# %% [markdown]
# E-commerce ETL Project Notebook

# %%
import pandas as pd

customerDF = pd.read_csv("../Data/raw/olist_customers_dataset.csv")
orderItemDF = pd.read_csv("../Data/raw/olist_order_items_dataset.csv")
orderPaymentDF = pd.read_csv("../Data/raw/olist_order_payments_dataset.csv")
orderDf = pd.read_csv("../Data/raw/olist_orders_dataset.csv")
productsDF = pd.read_csv("../Data/raw/olist_products_dataset.csv")
sellersDF = pd.read_csv("../Data/raw/olist_sellers_dataset.csv")

# %% [markdown]
# ### Profiling template that to follow
# # Preview
# df.head()
#
# # Basic Information
# df.shape
# df.columns.to_list()
#
# # Data Types
# df.dtypes
#
# # Missing Values
# df.isnull().sum()
#
# # Duplicate Rows
# df.duplicated().sum()
#
# # Candidate Key Check
# # (Depends on the table)

# %% [markdown]
# profiling the customer dataset

# %%
# customerDF.head(20)
# # print(customerDF.size)
# # print(customerDF.columns)
# # print(customerDF.info())
# # print(customerDF.shape)

# # print(customerDF.isnull().sum())

# # print(customerDF.duplicated().sum())

# print("Total Rows:", customerDF.shape[0])
# print("Unique customer_id:", customerDF["customer_id"].nunique())
# print("Unique customer_unique_id:", customerDF["customer_unique_id"].nunique())

# customer_counts = customerDF["customer_unique_id"].value_counts()
# print(customer_counts)
# repeated_customers = customer_counts[customer_counts > 1]

# print("Repeated customers:", len(repeated_customers))

# customerDF[
#     customerDF["customer_unique_id"].isin(repeated_customers.index)
# ].head(20)

print("Rows:", customerDF.shape[0])
print("Columns:", customerDF.shape[1])
print("Columns name:", customerDF.columns.to_list())
print("Missing values:", customerDF.isnull().sum())
print("Duplicated Row:", customerDF.duplicated().sum())
print("primary key: customer_id")

customerDF.dtypes
# Out:
# Rows: 99441
# Columns: 5
# Columns name: ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
# Missing values: customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# Duplicated Row: 0
# primary key: customer_id
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %% [markdown]
# profiling the orders dataset

# %%
# Basic Information
orderDf.shape
orderDf.columns.to_list()

# Data Types
orderDf.dtypes

# Missing Values
orderDf.isnull().sum()

# Duplicate Rows
orderDf.duplicated().sum()

# Candidate Primary Key
orderDf["order_id"].nunique()

# Business Understanding
orderDf["order_status"].unique()
orderDf["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %% [markdown]
# ### orders observation
# - column names are fine no change needed
# - data type of timestamps need to change
# - missing values for col - order_approved_at, order_delivered_carrier_date, order_delivered_customer_date
# - no duplicate value

# %% [markdown]
# profiling the orders items dataset

# %%
# basic info
orderItemDF.shape
orderItemDF.columns

# data type
orderItemDF.dtypes

# missing value
orderItemDF.isnull().sum()

#duplicate values
orderItemDF.duplicated().sum()

# candidate key investigation
orderItemDF["order_id"].nunique()
orderItemDF["order_item_id"].nunique()
# Out:
# 21

# %% [markdown]
# ### Order Items Observations
#
# - No duplicate rows.
# - No missing values.
# - `order_id` is not unique because one order can contain multiple items.
# - Candidate composite primary key: (`order_id`, `order_item_id`).

# %% [markdown]
# profiling the orders payment dataset

# %%
# preview
orderPaymentDF.head()

# basic info
orderPaymentDF.shape
orderPaymentDF.columns.to_list()

# datatype
orderPaymentDF.dtypes

# missing value
orderPaymentDF.isnull().sum()

# Duplicate rows
orderPaymentDF.duplicated().sum()

# candidate key investigation
orderPaymentDF["order_id"].nunique()
orderPaymentDF.shape[0]
orderPaymentDF.head(40)

#payment method value
orderPaymentDF["payment_type"].unique().tolist()

#Payment method counts
orderPaymentDF["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# ### Observations
#
# - No duplicate rows.
# - No missing values.
# - Multiple payment methods are available.
# - Credit card is the most common payment method.
# - Candidate composite primary key: (order_id, payment_sequential).

# %% [markdown]
# profiling the products dataset

# %%
# overview
productsDF.head(20)

# basic info
productsDF.shape
productsDF.columns.tolist()

# datatype
productsDF.dtypes

# missing value
productsDF.isnull().sum() 

# duplicate values
productsDF.duplicated().sum()

productsDF["product_category_name"].unique()
productsDF["product_category_name"].value_counts().to_dict()
# Out:
# {'cama_mesa_banho': 3029,
#  'esporte_lazer': 2867,
#  'moveis_decoracao': 2657,
#  'beleza_saude': 2444,
#  'utilidades_domesticas': 2335,
#  'automotivo': 1900,
#  'informatica_acessorios': 1639,
#  'brinquedos': 1411,
#  'relogios_presentes': 1329,
#  'telefonia': 1134,
#  'bebes': 919,
#  'perfumaria': 868,
#  'papelaria': 849,
#  'fashion_bolsas_e_acessorios': 849,
#  'cool_stuff': 789,
#  'ferramentas_jardim': 753,
#  'pet_shop': 719,
#  'eletronicos': 517,
#  'construcao_ferramentas_construcao': 400,
#  'eletrodomesticos': 370,
#  'malas_acessorios': 349,
#  'consoles_games': 317,
#  'moveis_escritorio': 309,
#  'instrumentos_musicais': 289,
#  'eletroportateis': 231,
#  'casa_construcao': 225,
#  'livros_interesse_geral': 216,
#  'fashion_calcados': 173,
#  'moveis_sala': 156,
#  'climatizacao': 124,
#  'livros_tecnicos': 123,
#  'telefonia_fixa': 116,
#  'casa_conforto': 111,
#  'market_place': 104,
#  'alimentos_bebidas': 104,
#  'fashion_roupa_masculina': 95,
# ...

# %% [markdown]
# ### observation
# - few column names are having spelling mistake ("
# ")
# - data type is fine
# - multiple missing values in all columns except product_id
# - no duplicate values
# - product_id is primary key

# %% [markdown]
# profiling the sellers dataset

# %%
# overview
sellersDF.head()

# basic info
sellersDF.shape
sellersDF.columns.tolist()

# data type
sellersDF.dtypes

# missing value
sellersDF.isnull().sum()

# duplicate value
sellersDF.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### observations
#
# - `seller_id` is the primary key
# - no missing value
# - no duplicate value

# %% [markdown]
# Cleaning phase

# %% [markdown]
# ### Cleaning Summary - Customers
#
# - No missing values found.
# - No duplicate rows found.
# - Data types are appropriate.
# - No invalid records identified.
# - No cleaning required.

# %% [markdown]
# orders DF cleaning

# %%
orderDf.head()

orderDf[orderDf["order_approved_at"].isnull()][
    ["order_id", "order_status", "order_purchase_timestamp", "order_approved_at"]
]

orderDf[orderDf["order_approved_at"].isnull()]["order_status"].value_counts()


orderDf[orderDf["order_delivered_carrier_date"].isnull()][
    [
        "order_id",
        "order_status",
        "order_purchase_timestamp",
        "order_delivered_carrier_date",
    ]
]

orderDf[orderDf["order_delivered_carrier_date"].isnull()]["order_status"].value_counts()



orderDf[orderDf["order_delivered_customer_date"].isnull()][
    [
        "order_id",
        "order_status",
        "order_purchase_timestamp",
        "order_delivered_customer_date",
    ]
]

orderDf[orderDf["order_delivered_customer_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %% [markdown]
# ### cleaning of orders
#
# - coverting the data type of object to datetime

# %%
date_col = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for col in date_col:
   orderDf[col] =  pd.to_datetime(orderDf[col])

orderDf.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Orders Cleaning Complete
#
# - Timestamp columns converted from object to datetime.
# - Row count unchanged.
# - Missing timestamp values retained as they represent valid business scenarios.
# - No duplicate rows removed.

# %% [markdown]
# ### products cleaning
# - rectifying misspelled column names i.e. product_name_lenght", "product_description_lenght", "product_weight_g

# %%
productsDF.rename(columns=
                  {"product_name_lenght":"product_name_length", 
                   "product_description_lenght":"product_description_length" }, inplace=True)

productsDF.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_length',
#        'product_description_length', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %% [markdown]
# ### order item cleaing

# %%
orderItemDF.columns.to_list()
orderItemDF.dtypes

orderItemDF["shipping_limit_date"] = pd.to_datetime(orderItemDF["shipping_limit_date"])

orderItemDF.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %% [markdown]
# ### cleaning payments
# - nothing to clean

# %%
orderPaymentDF.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %% [markdown]
# ### cleaning seller
# - nothing to clean

# %% [markdown]
# ### Transformation Phase

# %% [markdown]
# # orders

# %%
orderDf.head()

# calculating the days it took to deliver the order
orderDf["delivery_days"] = (orderDf["order_delivered_customer_date"]- orderDf["order_purchase_timestamp"]).dt.days

orderDf[
    [
        "order_purchase_timestamp",
        "order_delivered_customer_date",
        "delivery_days"
    ]
].head(10)

# finding the year in which order was placed
orderDf["order_year"] = orderDf["order_purchase_timestamp"].dt.year

# finding out the month in which order was placed
orderDf["order_month"] = orderDf["order_purchase_timestamp"].dt.month

# finding out the weekday in which order was placed
orderDf["order_weekday"] = orderDf["order_purchase_timestamp"].dt.day_name()

# How many days earlier or later was the order delivered compared with the estimated delivery date?

orderDf["delivery_vs_estimated_days"] = (
    orderDf["order_delivered_customer_date"]
    - orderDf["order_estimated_delivery_date"]
).dt.days

orderDf[
    [
        "order_delivered_customer_date",
        "order_estimated_delivery_date",
        "delivery_vs_estimated_days"
    ]
].head(10)


# How long did it take for an order to get approved after it was purchased?
orderDf["approval_time_hours"] = (orderDf["order_approved_at"] - orderDf["order_purchase_timestamp"]).dt.total_seconds()/3600

orderDf[
    [
        "order_approved_at",
        "order_purchase_timestamp",
        "approval_time_hours"
    ]
].head(10)


orderDf[
    [
        "order_id",
        "delivery_days",
        "order_year",
        "order_month",
        "order_weekday",
        "delivery_vs_estimated_days",
        "approval_time_hours"
    ]
].head(10)
# Out:
#                            order_id  delivery_days  order_year  order_month  \
# 0  e481f51cbdc54678b7cc49136f2d6af7            8.0        2017           10
# 1  53cdb2fc8bc7dce0b6741e2150273451           13.0        2018            7
# 2  47770eb9100c2d0c44946d9cf07ec65d            9.0        2018            8
# 3  949d5b44dbf5de918fe9c16f97b45f8a           13.0        2017           11
# 4  ad21c59c0840e6cb83a9ceb5573f8159            2.0        2018            2
# 5  a4591c265e18cb1dcee52889e2d8acc3           16.0        2017            7
# 6  136cce7faa42fdb2cefd53fdc79a6098            NaN        2017            4
# 7  6514b8ad8028c9f2cc2374ded245783f            9.0        2017            5
# 8  76c6e866289321a7c93b82b54852dc33            9.0        2017            1
# 9  e69bfb5eb88e0ed6a785585b27e16dbf           18.0        2017            7
#
#   order_weekday  delivery_vs_estimated_days  approval_time_hours
# 0        Monday                        -8.0             0.178333
# ...

# %% [markdown]
# ### transforming order items

# %%
orderItemDF

#We want to know the total value of each order item, including freight. so the logic is price* freight value

orderItemDF['total_item_value'] = orderItemDF["price"] + orderItemDF["freight_value"]

orderItemDF[
    [
        "order_id",
        "price",
        "freight_value",
        "total_item_value"
    ]
].head(10)
# Out:
#                            order_id   price  freight_value  total_item_value
# 0  00010242fe8c5a6d1ba2dd792cb16214   58.90          13.29             72.19
# 1  00018f77f2f0320c557190d7a144bdd3  239.90          19.93            259.83
# 2  000229ec398224ef6ca0657da4fc703e  199.00          17.87            216.87
# 3  00024acbcdf0a6daa1e931b038114c75   12.99          12.79             25.78
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  199.90          18.14            218.04
# 5  00048cc3ae777c65dbb7d2a0634bc1ea   21.90          12.69             34.59
# 6  00054e8431b9d7675808bcb819fb4a32   19.90          11.85             31.75
# 7  000576fe39319847cbb9d288c5617fa6  810.00          70.75            880.75
# 8  0005a1a1728c9d785b8e2b08b904576c  145.95          11.65            157.60
# 9  0005f50442cb953dcd1d21e1fb923495   53.99          11.40             65.39

# %% [markdown]
# ### Phase 4 — Data Integration

# %%
# merging the customer and orders DF

orderCustomerDf = pd.merge(
    orderDf, customerDF, how="left", on="customer_id"
)

orderCustomerDf
print("Orders before:", orderDf.shape[0])
print("After merge:", orderCustomerDf.shape[0])
orderCustomerDf.columns.tolist()
# Out:
# Orders before: 99441
# After merge: 99441
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'delivery_days',
#  'order_year',
#  'order_month',
#  'order_weekday',
#  'delivery_vs_estimated_days',
#  'approval_time_hours',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state']

# %%
# merging orders and order items

orderItemsCustomerDf = pd.merge(
    orderCustomerDf,
    orderItemDF,
    how="left",
    on="order_id"
)

orderItemsCustomerDf.shape
# Out:
# (113425, 25)

# %%
# merging product DF 

orderProductDf = pd.merge(
    orderItemsCustomerDf,
    productsDF,
    how="left",
    on="product_id"
)

orderProductDf.shape
orderProductDf.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# merging seller DF

masterDf = pd.merge(
    orderProductDf,
    sellersDF,
    how="left",
    on="seller_id"
)

masterDf.shape
masterDf.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## creating payment summary DF
# - since the payment DF has multiple payments per order we will have to merge all of the payment of single order.

# %%
# merging the orders 
paymentSummaryDF = orderPaymentDF.groupby("order_id")["payment_value"].sum()

# converting the series into DF 
paymentSummaryDF = paymentSummaryDF.reset_index()


# changing the column name 
paymentSummaryDF = paymentSummaryDF.rename(
    columns={"payment_value": "total_payment_value"}
)

paymentSummaryDF
paymentSummaryDF.head()
paymentSummaryDF.shape
# Out:
# (99440, 2)
